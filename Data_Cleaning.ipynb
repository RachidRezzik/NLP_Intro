# %% [markdown]
# # Problem:
#
# I would like to see if dave chappelle's comedic style is unique/similar to others.

# %% [markdown]
# # Data Collection / Source
#
# Scraps From The Loft: http://scrapsfromtheloft.com/
#
# Popular Comdey Specials (IMDB): https://www.imdb.com/

# %%
### Web Scraping ###
import requests
from bs4 import BeautifulSoup
import pickle

### Getting transcript data from Scraps From The Loft ###

def url_to_transcript(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'lxml')
    text = [p.text for p in soup.find(class_='post-content').find_all('p')]
    print(url)
    return text

### URLs of Comedy Special Transcripts ###
urls = ['http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/',
        'http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/',
        'http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/',
        'http://scrapsfromtheloft.com/2017/08/07/bo-burnham-2013-full-transcript/',
        'http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/',
        'http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/',
        'http://scrapsfromtheloft.com/2017/10/21/hasan-minhaj-homecoming-king-2017-full-transcript/',
        'http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/',
        'http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/']

### Comedian Names ###
comedians = ['louis', 'dave', 'ricky', 'bo', 'bill', 'jim', 'john', 'hasan', 'ali', 'anthony', 'mike', 'joe']

# %%
### Getting the Comedy Special Transcripts ###
transcripts = [url_to_transcript(url) for url in urls]
# Out:
# http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/
# http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/
# http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/
# http://scrapsfromtheloft.com/2017/08/07/bo-burnham-2013-full-transcript/
# http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/
# http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/
# http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/
# http://scrapsfromtheloft.com/2017/10/21/hasan-minhaj-homecoming-king-2017-full-transcript/
# http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/
# http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/
# http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/
# ...

# %%
### Pickle files for later use ###

# !mkdir transcripts

for i, c in enumerate(comedians):
    with open('transcripts/' + c + '.txt', 'wb') as file:
        pickle.dump(transcripts[i], file)

### Load Pickled Files ###
data = {}
for i, c in enumerate(comedians):
    with open('transcripts/' + c + '.txt', 'rb') as file:
        data[c] = pickle.load(file)

data.keys()
# Out:
# A subdirectory or file transcripts already exists.
# dict_keys(['louis', 'dave', 'ricky', 'bo', 'bill', 'jim', 'john', 'hasan', 'ali', 'anthony', 'mike', 'joe'])

# %%
data['louis'][:2]
# Out:
# ['Intro\nFade the music out. Let’s roll. Hold there. Lights. Do the lights. Thank you. Thank you very much. I appreciate that. I don’t necessarily agree with you, but I appreciate very much. Well, this is a nice place. This is easily the nicest place For many miles in every direction. That’s how you compliment a building And shit on a town with one sentence. It is odd around here, as I was driving here. There doesn’t seem to be any difference Between the sidewalk and the street for pedestrians here. People just kind of walk in the middle of the road. I love traveling And seeing all the different parts of the country. I live in New York. I live in a– There’s no value to your doing that at all.',
# ...

# %% [markdown]
# # Text Preprocessing

# %%
### Combining Text ###

def combine_text(list_of_text):
    combined_text = ' '.join(list_of_text)
    return combined_text

data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
### Creating Pandas DF from data_combined dict ###
import pandas as pd

scripts = pd.DataFrame.from_dict(data_combined).transpose()
scripts.columns = ['Transcript']

### Dave Chappelles Script ###
scripts.Transcript.loc['dave']
# Out:
# 'This is Dave. He tells dirty jokes for a living. That stare is where most of his hard work happens. It signifies a profound train of thought, the alchemist’s fire that transforms fear and tragedy into levity and livelihood. Dave calls that look “the trance.” ♪ Play me ♪ ♪ Buy me ♪ ♪ Workinonit ♪ ♪ Tune up ♪ ♪ Tune ♪ ♪ Oh ♪ ♪ Fade me ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ ♪ In every ghetto ♪ ♪ Ah-ah, ah-ah, ah-ah ♪ Thank you! Thank you very much! Thank you all. Oh, wow. That was exciting, wasn’t it? Thank you, guys. Have a seat, feel comfortable, relax. I want to thank everyone in LA for a wonderful week. It’s been great here. You know what? It’s been ten years since the last time I played Los Angeles, if you can imagine. I know! I know, I’ve been gone for a very long time. And un
# ...

# %%
### Lowercase, remove text in square brackets, punctuation, words containing numbers ###
import re
import string 

def clean_text1(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

scripts.Transcript.apply(lambda x: clean_text1(x))
# Out:
# louis      introfade the music out lets roll hold there l...
# dave       this is dave he tells dirty jokes for a living...
# ricky      hello hello how you doing great thank you wow ...
# bo         bo what old macdonald had a farm e i e i o and...
# bill        all right thank you thank you very much thank...
# jim           ladies and gentlemen please welcome to the ...
# john       all right petunia wish me luck out there you w...
# hasan        whats up davis whats up im home i had to bri...
# ali        ladies and gentlemen please welcome to the sta...
# anthony    thank you thank you thank you san francisco th...
# mike       wow hey thank you thanks thank you guys hey se...
# joe           ladies and gentlemen welcome joe rogan  wha...
# Name: Transcript, dtype: object

# %%
### Add Comedian Names to DF ###
full_names = ['Ali Wong', 'Anthony Jeselnik', 'Bill Burr', 'Bo Burnham', 'Dave Chappelle', 'Hasan Minhaj',
              'Jim Jefferies', 'Joe Rogan', 'John Mulaney', 'Louis C.K.', 'Mike Birbiglia', 'Ricky Gervais']

scripts['comedian'] = full_names

# %%
### Document Term Matrix ### 
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(scripts.Transcript)
script_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
script_dtm.index = scripts.index

# %%
script_dtm.head(2)
# Out:
#        00  000  01  05  07  08  10  100  11  114  ...  zee  zen  zeppelin  \
# louis   1    0   0   0   0   0   1    1   0    1  ...    0    0         0
# dave    0    3   0   0   0   0   1    0   2    0  ...    0    0         0
#
#        zero  zillion  zombie  zombies  zoning  zoo  éclair
# louis     2        0       0        0       0    0       0
# dave      0        0       0        0       0    0       0
#
# [2 rows x 7322 columns]

# %%
### Top 10 words for each comedian ###
top_10 = {}
for w in script_dtm.columns:
    top = script_dtm[w].sort_values(ascending=False).head(10)
    top_10[w] = list(zip(top.index, top.values))

for comedian, top_words in top_10.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:9]]))
    print('---')
# Out:
# 00
# mike, bill, john, jim, louis, joe, anthony, ali, hasan
# ---
# 000
# jim, joe, ricky, hasan, dave, john, mike, ali, anthony
# ---
# 01
# hasan, joe, mike, anthony, ali, john, jim, bill, bo
# ---
# 05
# bill, joe, mike, anthony, ali, hasan, john, jim, bo
# ---
# 07
# bill, joe, mike, anthony, ali, hasan, john, jim, bo
# ---
# 08
# bill, joe, mike, anthony, ali, hasan, john, jim, bo
# ---
# 10
# joe, jim, mike, ali, bill, dave, louis, anthony, hasan
# ---
# 100
# ricky, joe, anthony, ali, john, bill, louis, mike, hasan
# ---
# 11
# joe, anthony, hasan, dave, mike, bill, bo, ali, john
# ---
# 114
# louis, joe, mike, anthony, ali, hasan, john, jim, bill
# ---
# 115
# bill, joe, mike, anthony, ali, hasan, john, jim, bo
# ---
# 11th
# hasan, bill, joe, mike, anthony, ali, john, jim, bo
# ---
# 12
# hasan, mike, john, bill, ricky, dave, joe, anthony, ali
# ---
# 120
# bill, joe, mike, anthony, ali, hasan, john, jim, bo
# ---
# 125
# ...
